# %% [markdown]
# ### Messages
#
# Messages are the fundamental until of context for models in Langchain.They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM. Messages are objects that contain:
# - Role - Identifies the message type (ex: System, User)
# - Content - Represents the actual content of the message (like text, images, audio, documnets, etc.)
# - Metadata - Optional fields such as response information, message IDs, and token usage.
#
# LangChain provides a standard message type that works across all model providers, ensuring consistent behavior regardless of the model being called.

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:qwen/qwen3.6-27b")

# %%
model.invoke("what is AI?")#Human Input/Message
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Query**: The user asks "what is AI?" - a broad, foundational question about Artificial Intelligence.\n\n2.  **Identify Key Components to Cover**:\n   - Definition of AI\n   - Core concepts (machine learning, deep learning, neural networks)\n   - Types/Capabilities (narrow vs. general AI)\n   - How it works (data, algorithms, training)\n   - Applications/Examples\n   - Current state & limitations\n   - Keep it clear, concise, and accessible\n\n3.  **Draft - Mental Refinement**:\n   AI (Artificial Intelligence) refers to computer systems designed to perform tasks that typically require human intelligence. These tasks include understanding language, recognizing patterns, solving problems, learning from experience, and making decisions.\n\n   Key points to include:\n   - It\'s not a single technology but a broad field\n   - Machine learning (ML) and deep learning are major subsets\n   - AI learns from data
# ...

# %% [markdown]
# ### Text Prompts
#
# Text Prompts are strings - ideal for straightforward generation tasks where you dont need to retain conversation history.

# %%
model.invoke("what is langchain?")
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Query**: The user asks "what is langchain?" - a straightforward question about a specific technology/framework.\n\n2.  **Identify Key Concepts**: \n   - LangChain is a framework/library\n   - It\'s designed for building applications with Large Language Models (LLMs)\n   - Key features: chaining components, managing context, integrating with external tools/data sources\n   - Use cases: chatbots, agents, RAG (Retrieval-Augmented Generation), workflow automation\n   - Language: Primarily Python and JavaScript/TypeScript\n   - Open source, widely adopted\n\n3.  **Structure the Response**:\n   - Definition/Overview\n   - Core Purpose/Problem it solves\n   - Key Features/Components\n   - Common Use Cases\n   - Languages & Ecosystem\n   - Current Status/Context (as of 2024/2025)\n   - Keep it concise and accurate\n\n4.  **Draft - Mental Refinement**:\n   LangChain is an open-source framework designed to simpl
# ...

# %% [markdown]
# use text prompts when:
#
# - You have a single, standalone request
# - You dont eed convo history
# - You want minimal code complexity

# %% [markdown]
# ### Message Prompts
#
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.
#
# Message types:
# - System message: Tells the model how to behave and provide context for interactions
# - Human messages: Represents user input and interactions with the model
# - AI Message: Responses generated by the model, including text content, tool calls, and metadata.
# - Tool Message - Represents the outputs of tool calls

# %% [markdown]
# ### System Message
#
# A system Message represent an initial set of instructions that primes the model's behavior. You can use a system message to set the tone, define the model's role, and establish guidelines for responses.

# %% [markdown]
# ### Human Message
#
# A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodel content.

# %% [markdown]
# ### AI Message
#
# An Ai Message represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.

# %% [markdown]
# ### Tool Message
#
# For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage("You are a petry expert"),
    HumanMessage("Write a poem on AI")
]

response = model.invoke(messages)
response.content
# Out:
# '\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - **Topic:** AI (Artificial Intelligence)\n   - **Format:** Poem\n   - **Role:** Poetry expert (implied by system prompt)\n\n2.  **Identify Key Themes/Concepts about AI:**\n   - Creation/Origin (human-made, code, data)\n   - Learning/Evolution (training, neural networks, adaptation)\n   - Capabilities (reasoning, creativity, speed, memory)\n   - Ambiguity/Mystery (black box, consciousness debate, human-like but not human)\n   - Relationship with humans (tool, partner, mirror, future)\n   - Tone: Reflective, awe-inspiring, slightly philosophical, balanced (neither purely utopian nor dystopian)\n\n3.  **Determine Poetic Structure & Style:**\n   - Form: Free verse or structured stanzas? I\'ll go with structured quatrains for rhythm and readability, with a consistent meter (roughly iambic) and rhyme scheme (ABAB or AABB). Let\'s aim for ABAB for elegance.\n   - Language: Evocative, precise, metaphor-rich, avoiding
# ...

# %%
system_msg = SystemMessage("you are a helpful codinh assistant.")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Query:** The user asks "How do I create a REST API?" This is a broad, foundational question. I need to provide a clear, structured, and actionable guide that covers the essential concepts, steps, and tools, while keeping it accessible for beginners but useful for intermediate developers.
#
# 2.  **Identify Key Components of a REST API:**
#    - What is REST? (Representational State Transfer)
#    - Core principles/resources, HTTP methods, status codes, statelessness, etc.
#    - Tech stack choices (language, framework, database)
#    - Step-by-step creation process
#    - Best practices
#    - Example/Code snippet (optional but helpful)
#    - Testing & deployment
#
# 3.  **Structure the Response:**
#    - Introduction: Briefly explain what a REST API is
#    - Step 1: Choose your tech stack
#    - Step 2: Set up the project
#    - Step 3: Define resources & endpoints
#    - Step 4: Implement CRUD operations
# ...

# %%
## detailed info to LLM through system message 
from langchain.messages import SystemMessage, HumanMessage

system_msg = SystemMessage("""
You are a senior python developer with expertise in web frameworks. Always provide code examples and explain your reasoning. Be concise but thorough in your explanations
""")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Query:** The user asks "How do I create a REST API?" This is a broad question. I need to provide a clear, concise, yet thorough guide with code examples, focusing on Python since I'm positioned as a senior Python developer with web framework expertise.
#
# 2.  **Identify Key Components of a REST API:**
#    - What is REST? (Brief context)
#    - Core principles (stateless, resource-based, HTTP methods, status codes)
#    - Tools/Frameworks needed (Python ecosystem: FastAPI, Flask, Django REST Framework)
#    - I'll choose **FastAPI** as the primary example because it's modern, fast, well-documented, type-hinted, and widely adopted for new projects. I'll also mention Flask/DRF as alternatives.
#    - Steps to create one:
#      a. Setup environment
#      b. Install dependencies
#      c. Define data models/schemas
#      d. Create routes/endpoints
#      e. Run & test
#    - Provide a complete, runnable example
# ...

# %%
### Message Metadata
human_msg = HumanMessage(
    content="Hello!",
    name="alice", #optional: identify different users
    id="msg_123", #optional: unique id for tracing
)

# %%
response = model.invoke([
    human_msg
])
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - User said: "Hello!"\n   - This is a standard greeting, open-ended, and requires a friendly, welcoming response.\n\n2.  **Identify Key Requirements:**\n   - Acknowledge the greeting\n   - Maintain a friendly and helpful tone\n   - Invite further conversation or offer assistance\n   - Keep it concise\n\n3.  **Formulate Response (Mental Draft):**\n   Hello! How can I assist you today? Whether you have a question, need help with something, or just want to chat, I\'m here for you. 😊\n\n4.  **Refine Response:**\n   - Check tone: Friendly, professional, approachable\n   - Check length: Short and to the point\n   - Check purpose: Opens the door for the user\'s actual request\n   - Matches AI assistant guidelines\n\n   The draft looks good. No major changes needed.\n\n5.  **Final Output Generation:** (matches the refined version)\n   "Hello! How can I help you today? 😊" (Slightly more concise while 
# ...

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage

#create an AI message manually(2x: for a convo history)
ai_msg = AIMessage("T'd be happy to help you with that question!")

#Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg, # Insert as if it came from the model
    HumanMessage("Great! what's 2+2")
]

response = model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Analyze User Input:** The user asks "Great! what's 2+2"
# 2.  **Identify Core Question:** The question is a simple arithmetic problem: 2 + 2.
# 3.  **Calculate/Verify:** 2 + 2 = 4. This is a basic mathematical fact.
# 4.  **Formulate Response:** Keep it clear, direct, and friendly. "2 + 2 equals 4!" or "That's 4!"
# 5.  **Check for Tone/Context:** The user said "Great!" so maintain a positive, helpful tone.
# 6.  **Final Output Generation:** "2 + 2 equals 4! Let me know if you need help with anything else." (Simple, accurate, open-ended for follow-up)✅
# </think>
#
# 2 + 2 equals **4**! Let me know if you have any other questions or need help with something else. 😊

# %%
response.usage_metadata
# Out:
# {'input_tokens': 54, 'output_tokens': 208, 'total_tokens': 262}

# %%
from langchain.messages import AIMessage
from langchain.messages import ToolMessage

#After a model makes a tool call
# here, we demonstrate manually creating the messages for brevity
ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name":"get_weather",
        "args":{"location": "San Francisco"},
        "id":"call_123"
    }]
)

#Execute tool and create result messages 
weather_result = "Sunny , 72F"
tool_message = ToolMessage(
    content=weather_result,
    tool_call_id = "call_123" #must match the call ID
)

#continue convo
messages = [
    HumanMessage("Whats the weather in San Francisco?"),
    ai_message, #Model's tool call
    tool_message, # Tool execution resuly
]

response = model.invoke(messages) # model processes the result

# %%
tool_message
# Out:
# ToolMessage(content='Sunny , 72F', tool_call_id='call_123')
